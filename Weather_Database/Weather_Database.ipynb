# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 795

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all cities in our list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | flin flon
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | nizhniy tsasuchey
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | borivka
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | aksarka
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 14 of Set 1 | solnechnyy
# Processing Record 15 of Set 1 | guerrero negro
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 1 | shulan
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | rongcheng
# Processing Record 27 of Set 1 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 28 of Set 1 | sioux falls
# Processing Record 29 of Set 1 | ipameri
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | grahamstown
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | namibe
# City not found. Skipping...
# Processing Record 34 of Set 1 | halifax
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | marilia
# Processing Record 38 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | khorixas
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | dangriga
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | altamira
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | biggar
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | havoysund
# Processing Record 3 of Set 2 | kieta
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | tiptur
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | astoria
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | svetlogorsk
# Processing Record 11 of Set 2 | kalmunai
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | ratlam
# Processing Record 15 of Set 2 | vengerovo
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | sechura
# Processing Record 18 of Set 2 | hangzhou
# Processing Record 19 of Set 2 | rocha
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | niono
# Processing Record 22 of Set 2 | mayo
# Processing Record 23 of Set 2 | chancay
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | saldanha
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | chifeng
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | zhangye
# Processing Record 30 of Set 2 | saraiu
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | taksimo
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | bar harbor
# Processing Record 35 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | kijang
# Processing Record 39 of Set 2 | mongoumba
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | kolpashevo
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | ambilobe
# Processing Record 45 of Set 2 | rio maior
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 2 | dublin
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 | betioky
# Processing Record 3 of Set 3 | kununurra
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | marsa matruh
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | alice springs
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | kvarkeno
# Processing Record 14 of Set 3 | costa rica
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | tanout
# Processing Record 17 of Set 3 | green river
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | kipini
# Processing Record 20 of Set 3 | ostroleka
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 3 | riberalta
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | vanimo
# Processing Record 26 of Set 3 | san jeronimo
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | wajir
# Processing Record 29 of Set 3 | nizhniy kuranakh
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | beringovskiy
# Processing Record 32 of Set 3 | conde
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | haines junction
# Processing Record 35 of Set 3 | lianzhou
# Processing Record 36 of Set 3 | stony mountain
# Processing Record 37 of Set 3 | port keats
# Processing Record 38 of Set 3 | poum
# Processing Record 39 of Set 3 | praya
# Processing Record 40 of Set 3 | samarai
# Processing Record 41 of Set 3 | luxor
# Processing Record 42 of Set 3 | vanderhoof
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | scarborough
# Processing Record 46 of Set 3 | luderitz
# Processing Record 47 of Set 3 | marawi
# Processing Record 48 of Set 3 | barquisimeto
# Processing Record 49 of Set 3 | paita
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | luganville
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | celestun
# Processing Record 4 of Set 4 | pathein
# Processing Record 5 of Set 4 | inhambane
# Processing Record 6 of Set 4 | cocobeach
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | qeshm
# Processing Record 9 of Set 4 | lagoa
# Processing Record 10 of Set 4 | verkh-usugli
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | marevo
# Processing Record 15 of Set 4 | barra da estiva
# Processing Record 16 of Set 4 | boo
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | iquitos
# Processing Record 19 of Set 4 | karratha
# Processing Record 20 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 21 of Set 4 | belaya gora
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | mnogovershinnyy
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | tuatapere
# Processing Record 27 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 4 | zhigansk
# Processing Record 29 of Set 4 | vitim
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | yerbogachen
# Processing Record 32 of Set 4 | andros town
# Processing Record 33 of Set 4 | sycamore
# Processing Record 34 of Set 4 | letka
# Processing Record 35 of Set 4 | murgab
# Processing Record 36 of Set 4 | saint-paul
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | vasai
# Processing Record 39 of Set 4 | comodoro rivadavia
# Processing Record 40 of Set 4 | mehamn
# Processing Record 41 of Set 4 | masterton
# Processing Record 42 of Set 4 | sobolevo
# Processing Record 43 of Set 4 | burica
# City not found. Skipping...
# Processing Record 44 of Set 4 | honningsvag
# Processing Record 45 of Set 4 | knysna
# Processing Record 46 of Set 4 | saint-philippe
# Processing Record 47 of Set 4 | yellowknife
# Processing Record 48 of Set 4 | monastyrshchina
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | oistins
# Processing Record 1 of Set 5 | nanakuli
# Processing Record 2 of Set 5 | junin
# Processing Record 3 of Set 5 | maceio
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | southbridge
# Processing Record 6 of Set 5 | kamennogorsk
# Processing Record 7 of Set 5 | tierralta
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | fremont
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | port-gentil
# Processing Record 12 of Set 5 | sioux lookout
# Processing Record 13 of Set 5 | trincomalee
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | ciney
# Processing Record 16 of Set 5 | prabumulih
# Processing Record 17 of Set 5 | uren
# Processing Record 18 of Set 5 | ulaangom
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | avera
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | yulara
# Processing Record 27 of Set 5 | baon
# Processing Record 28 of Set 5 | umm lajj
# Processing Record 29 of Set 5 | rudnaya pristan
# Processing Record 30 of Set 5 | perth
# Processing Record 31 of Set 5 | souillac
# Processing Record 32 of Set 5 | tasiilaq
# Processing Record 33 of Set 5 | englewood
# Processing Record 34 of Set 5 | rio gallegos
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | robertsport
# Processing Record 38 of Set 5 | diego de almagro
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | turukhansk
# Processing Record 41 of Set 5 | aybak
# City not found. Skipping...
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | la colmena
# Processing Record 46 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 5 | batemans bay
# Processing Record 48 of Set 5 | bairiki
# Processing Record 49 of Set 5 | nuuk
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | abeche
# Processing Record 2 of Set 6 | urumqi
# Processing Record 3 of Set 6 | nogliki
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | tavda
# Processing Record 6 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 6 | knokke-heist
# Processing Record 8 of Set 6 | marsh harbour
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | nanortalik
# Processing Record 11 of Set 6 | miedzychod
# Processing Record 12 of Set 6 | dikson
# Processing Record 13 of Set 6 | kochubey
# Processing Record 14 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 6 | vilyuysk
# Processing Record 16 of Set 6 | arlit
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | atbasar
# Processing Record 19 of Set 6 | evensk
# Processing Record 20 of Set 6 | jilotepec
# Processing Record 21 of Set 6 | huron
# Processing Record 22 of Set 6 | bara
# Processing Record 23 of Set 6 | hit
# Processing Record 24 of Set 6 | hanna
# Processing Record 25 of Set 6 | kuopio
# Processing Record 26 of Set 6 | nouadhibou
# Processing Record 27 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 6 | waddan
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | buwenge
# Processing Record 31 of Set 6 | bartica
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | mazagao
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | kindu
# Processing Record 36 of Set 6 | santa isabel
# Processing Record 37 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | mayumba
# Processing Record 40 of Set 6 | te anau
# Processing Record 41 of Set 6 | lorengau
# Processing Record 42 of Set 6 | general cepeda
# Processing Record 43 of Set 6 | cap-aux-meules
# Processing Record 44 of Set 6 | mahanoro
# Processing Record 45 of Set 6 | chincha alta
# Processing Record 46 of Set 6 | aykhal
# Processing Record 47 of Set 6 | sulangan
# Processing Record 48 of Set 6 | talnakh
# Processing Record 49 of Set 6 | balclutha
# Processing Record 50 of Set 6 | kawalu
# Processing Record 1 of Set 7 | nan
# Processing Record 2 of Set 7 | khor
# Processing Record 3 of Set 7 | moerai
# Processing Record 4 of Set 7 | twin falls
# Processing Record 5 of Set 7 | cururupu
# Processing Record 6 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 7 | ust-uda
# Processing Record 8 of Set 7 | puerto leguizamo
# Processing Record 9 of Set 7 | santa rosa
# Processing Record 10 of Set 7 | tucumcari
# Processing Record 11 of Set 7 | baruun-urt
# Processing Record 12 of Set 7 | douglas
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | lakes entrance
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | fairbanks
# Processing Record 17 of Set 7 | hirara
# Processing Record 18 of Set 7 | kilindoni
# Processing Record 19 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 7 | shaowu
# Processing Record 21 of Set 7 | chabahar
# Processing Record 22 of Set 7 | grand island
# Processing Record 23 of Set 7 | zheleznodorozhnyy
# Processing Record 24 of Set 7 | lethem
# Processing Record 25 of Set 7 | byron bay
# Processing Record 26 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 7 | maragogi
# Processing Record 29 of Set 7 | la primavera
# Processing Record 30 of Set 7 | awbari
# Processing Record 31 of Set 7 | kilcullen
# Processing Record 32 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 7 | wattegama
# Processing Record 34 of Set 7 | tete
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | ushtobe
# Processing Record 37 of Set 7 | sao miguel do araguaia
# Processing Record 38 of Set 7 | gamba
# Processing Record 39 of Set 7 | okmulgee
# Processing Record 40 of Set 7 | hachinohe
# Processing Record 41 of Set 7 | hofn
# Processing Record 42 of Set 7 | xining
# Processing Record 43 of Set 7 | marana
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | bandiagara
# Processing Record 46 of Set 7 | port pirie
# Processing Record 47 of Set 7 | turku
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | codrington
# Processing Record 50 of Set 7 | sandane
# Processing Record 1 of Set 8 | saint albans
# Processing Record 2 of Set 8 | kijabe
# Processing Record 3 of Set 8 | poya
# Processing Record 4 of Set 8 | cap malheureux
# Processing Record 5 of Set 8 | namtsy
# Processing Record 6 of Set 8 | westport
# Processing Record 7 of Set 8 | whitianga
# Processing Record 8 of Set 8 | akyab
# Processing Record 9 of Set 8 | cidreira
# Processing Record 10 of Set 8 | kavieng
# Processing Record 11 of Set 8 | salisbury
# Processing Record 12 of Set 8 | san luis rio colorado
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | yar-sale
# Processing Record 15 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 16 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 8 | vila franca do campo
# Processing Record 19 of Set 8 | hervey bay
# Processing Record 20 of Set 8 | garowe
# Processing Record 21 of Set 8 | hobbs
# Processing Record 22 of Set 8 | belmonte
# Processing Record 23 of Set 8 | berdigestyakh
# Processing Record 24 of Set 8 | ambon
# Processing Record 25 of Set 8 | harrisonville
# Processing Record 26 of Set 8 | ankara
# Processing Record 27 of Set 8 | atar
# Processing Record 28 of Set 8 | okha
# Processing Record 29 of Set 8 | vardo
# Processing Record 30 of Set 8 | kalabo
# Processing Record 31 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 8 | morant bay
# Processing Record 33 of Set 8 | motril
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | kaitangata
# Processing Record 36 of Set 8 | grand-santi
# Processing Record 37 of Set 8 | bah
# Processing Record 38 of Set 8 | mednogorsk
# Processing Record 39 of Set 8 | clyde river
# Processing Record 40 of Set 8 | vaitape
# Processing Record 41 of Set 8 | llano largo
# Processing Record 42 of Set 8 | sisimiut
# Processing Record 43 of Set 8 | port hedland
# Processing Record 44 of Set 8 | uddevalla
# Processing Record 45 of Set 8 | illapel
# Processing Record 46 of Set 8 | provideniya
# Processing Record 47 of Set 8 | ritchie
# Processing Record 48 of Set 8 | menongue
# Processing Record 49 of Set 8 | taybad
# Processing Record 50 of Set 8 | ende
# Processing Record 1 of Set 9 | sangar
# Processing Record 2 of Set 9 | taltal
# Processing Record 3 of Set 9 | viedma
# Processing Record 4 of Set 9 | pattaya
# Processing Record 5 of Set 9 | jimeta
# Processing Record 6 of Set 9 | fagernes
# Processing Record 7 of Set 9 | synya
# Processing Record 8 of Set 9 | antas
# Processing Record 9 of Set 9 | pinhao
# Processing Record 10 of Set 9 | hobyo
# Processing Record 11 of Set 9 | vestmanna
# Processing Record 12 of Set 9 | wanning
# Processing Record 13 of Set 9 | gualeguaychu
# Processing Record 14 of Set 9 | imbituba
# Processing Record 15 of Set 9 | la ronge
# Processing Record 16 of Set 9 | fortuna foothills
# Processing Record 17 of Set 9 | dobryanka
# Processing Record 18 of Set 9 | ilhabela
# Processing Record 19 of Set 9 | ndele
# Processing Record 20 of Set 9 | brownwood
# Processing Record 21 of Set 9 | khani
# Processing Record 22 of Set 9 | bonthe
# Processing Record 23 of Set 9 | bandrele
# Processing Record 24 of Set 9 | alepe
# Processing Record 25 of Set 9 | nyirmeggyes
# Processing Record 26 of Set 9 | wajima
# Processing Record 27 of Set 9 | tilichiki
# Processing Record 28 of Set 9 | pafos
# Processing Record 29 of Set 9 | ostersund
# Processing Record 30 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 31 of Set 9 | bathsheba
# Processing Record 32 of Set 9 | muzhi
# Processing Record 33 of Set 9 | kendal
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | erenhot
# Processing Record 36 of Set 9 | perevoz
# Processing Record 37 of Set 9 | chapais
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | urtenen
# Processing Record 40 of Set 9 | gweta
# Processing Record 41 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | havelock
# Processing Record 44 of Set 9 | jacareacanga
# Processing Record 45 of Set 9 | terrace
# Processing Record 46 of Set 9 | campos novos
# Processing Record 47 of Set 9 | warri
# Processing Record 48 of Set 9 | trairi
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | chom bung
# City not found. Skipping...
# Processing Record 1 of Set 10 | naliya
# Processing Record 2 of Set 10 | mwaro
# Processing Record 3 of Set 10 | changying
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | jingdezhen
# Processing Record 6 of Set 10 | palapye
# Processing Record 7 of Set 10 | mzimba
# Processing Record 8 of Set 10 | la baule-escoublac
# Processing Record 9 of Set 10 | regen
# Processing Record 10 of Set 10 | strelka
# Processing Record 11 of Set 10 | the valley
# Processing Record 12 of Set 10 | sibolga
# Processing Record 13 of Set 10 | freeport
# Processing Record 14 of Set 10 | sabzevar
# Processing Record 15 of Set 10 | woonsocket
# Processing Record 16 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 10 | buraydah
# Processing Record 18 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 10 | chhapar
# Processing Record 21 of Set 10 | kudahuvadhoo
# Processing Record 22 of Set 10 | kutum
# Processing Record 23 of Set 10 | virtsu
# Processing Record 24 of Set 10 | tiznit
# Processing Record 25 of Set 10 | abilene
# Processing Record 26 of Set 10 | margate
# Processing Record 27 of Set 10 | oyem
# Processing Record 28 of Set 10 | zaoyang
# Processing Record 29 of Set 10 | carutapera
# Processing Record 30 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 10 | paamiut
# Processing Record 32 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 10 | himora
# City not found. Skipping...
# Processing Record 34 of Set 10 | zyryanka
# Processing Record 35 of Set 10 | mecca
# Processing Record 36 of Set 10 | pochutla
# Processing Record 37 of Set 10 | bilibino
# Processing Record 38 of Set 10 | louis trichardt
# Processing Record 39 of Set 10 | ixtapa
# Processing Record 40 of Set 10 | huainan
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | russell
# Processing Record 43 of Set 10 | tamale
# Processing Record 44 of Set 10 | antofagasta
# Processing Record 45 of Set 10 | santa cruz
# Processing Record 46 of Set 10 | kolondieba
# Processing Record 47 of Set 10 | beruwala
# Processing Record 48 of Set 10 | sarahan
# Processing Record 49 of Set 10 | palauig
# Processing Record 50 of Set 10 | oksfjord
# Processing Record 1 of Set 11 | isla mujeres
# Processing Record 2 of Set 11 | ayia galini
# Processing Record 3 of Set 11 | cody
# Processing Record 4 of Set 11 | alugan
# Processing Record 5 of Set 11 | broome
# Processing Record 6 of Set 11 | tual
# Processing Record 7 of Set 11 | karatau
# Processing Record 8 of Set 11 | raga
# Processing Record 9 of Set 11 | eagle
# Processing Record 10 of Set 11 | tornio
# Processing Record 11 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 11 | beloha
# Processing Record 13 of Set 11 | killybegs
# Processing Record 14 of Set 11 | harnosand
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | sabang
# Processing Record 17 of Set 11 | dukat
# Processing Record 18 of Set 11 | beibei
# Processing Record 19 of Set 11 | plainfield
# Processing Record 20 of Set 11 | behshahr
# Processing Record 21 of Set 11 | mukhtolovo
# Processing Record 22 of Set 11 | maiduguri
# Processing Record 23 of Set 11 | meulaboh
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 26 of Set 11 | santa vitoria
# Processing Record 27 of Set 11 | plettenberg bay
# Processing Record 28 of Set 11 | nantucket
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | kashi
# Processing Record 31 of Set 11 | pacific grove
# Processing Record 32 of Set 11 | yumen
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | inirida
# Processing Record 35 of Set 11 | ningan
# City not found. Skipping...
# Processing Record 36 of Set 11 | san cristobal
# Processing Record 37 of Set 11 | visnes
# Processing Record 38 of Set 11 | chicama
# Processing Record 39 of Set 11 | le creusot
# Processing Record 40 of Set 11 | bolobo
# Processing Record 41 of Set 11 | grootfontein
# Processing Record 42 of Set 11 | ubinskoye
# Processing Record 43 of Set 11 | lufilufi
# Processing Record 44 of Set 11 | makat
# Processing Record 45 of Set 11 | auki
# Processing Record 46 of Set 11 | nemuro
# Processing Record 47 of Set 11 | kattivakkam
# Processing Record 48 of Set 11 | ust-ishim
# Processing Record 49 of Set 11 | taraz
# Processing Record 50 of Set 11 | srisailam
# Processing Record 1 of Set 12 | antipolo
# Processing Record 2 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 12 | dzerzhinsk
# Processing Record 4 of Set 12 | werda
# Processing Record 5 of Set 12 | big spring
# Processing Record 6 of Set 12 | isangel
# Processing Record 7 of Set 12 | sile
# Processing Record 8 of Set 12 | hornepayne
# Processing Record 9 of Set 12 | cape canaveral
# Processing Record 10 of Set 12 | idil
# Processing Record 11 of Set 12 | guacimo
# Processing Record 12 of Set 12 | manono
# Processing Record 13 of Set 12 | alihe
# Processing Record 14 of Set 12 | formosa do rio preto
# Processing Record 15 of Set 12 | vestmannaeyjar
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | salekhard
# Processing Record 18 of Set 12 | zemio
# Processing Record 19 of Set 12 | porto santo
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | methoni
# Processing Record 23 of Set 12 | lata
# Processing Record 24 of Set 12 | asau
# Processing Record 25 of Set 12 | rajsamand
# Processing Record 26 of Set 12 | constitucion
# Processing Record 27 of Set 12 | wencheng
# Processing Record 28 of Set 12 | skibbereen
# Processing Record 29 of Set 12 | camana
# Processing Record 30 of Set 12 | ise
# Processing Record 31 of Set 12 | oktyabrskoye
# Processing Record 32 of Set 12 | caohai
# Processing Record 33 of Set 12 | moa
# Processing Record 34 of Set 12 | jalu
# Processing Record 35 of Set 12 | warrington
# Processing Record 36 of Set 12 | saint-ambroise
# Processing Record 37 of Set 12 | kruisfontein
# Processing Record 38 of Set 12 | saint pete beach
# Processing Record 39 of Set 12 | komsomolskiy
# Processing Record 40 of Set 12 | kletnya
# Processing Record 41 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 42 of Set 12 | gravelbourg
# Processing Record 43 of Set 12 | fairview
# Processing Record 44 of Set 12 | mattru
# Processing Record 45 of Set 12 | aasiaat
# Processing Record 46 of Set 12 | puerto el triunfo
# Processing Record 47 of Set 12 | general pico
# Processing Record 48 of Set 12 | lucatan
# City not found. Skipping...
# Processing Record 49 of Set 12 | miraflores
# Processing Record 50 of Set 12 | lamu
# Processing Record 1 of Set 13 | berlevag
# Processing Record 2 of Set 13 | port macquarie
# Processing Record 3 of Set 13 | santiago
# Processing Record 4 of Set 13 | nchelenge
# Processing Record 5 of Set 13 | luwuk
# Processing Record 6 of Set 13 | ipixuna
# Processing Record 7 of Set 13 | awjilah
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | anadyr
# Processing Record 10 of Set 13 | contamana
# Processing Record 11 of Set 13 | mawlamyine
# Processing Record 12 of Set 13 | muli
# Processing Record 13 of Set 13 | lincoln
# Processing Record 14 of Set 13 | alyangula
# Processing Record 15 of Set 13 | el tigre
# Processing Record 16 of Set 13 | bambanglipuro
# Processing Record 17 of Set 13 | bomet
# Processing Record 18 of Set 13 | lavrentiya
# Processing Record 19 of Set 13 | tirumala
# Processing Record 20 of Set 13 | keuruu
# Processing Record 21 of Set 13 | la palma
# Processing Record 22 of Set 13 | berkak
# Processing Record 23 of Set 13 | road town
# Processing Record 24 of Set 13 | abonnema
# Processing Record 25 of Set 13 | sembe
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | sorong
# Processing Record 28 of Set 13 | pauini
# Processing Record 29 of Set 13 | hilton head island
# Processing Record 30 of Set 13 | jiuquan
# Processing Record 31 of Set 13 | puerto escondido
# Processing Record 32 of Set 13 | kalengwa
# Processing Record 33 of Set 13 | college
# Processing Record 34 of Set 13 | mapiripan
# Processing Record 35 of Set 13 | usakos
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 38 of Set 13 | valera
# Processing Record 39 of Set 13 | neftcala
# Processing Record 40 of Set 13 | paso de carrasco
# Processing Record 41 of Set 13 | colares
# Processing Record 42 of Set 13 | jhargram
# Processing Record 43 of Set 13 | laki
# Processing Record 44 of Set 13 | nidzica
# Processing Record 45 of Set 13 | pemberton
# Processing Record 46 of Set 13 | aquiraz
# Processing Record 47 of Set 13 | churapcha
# Processing Record 48 of Set 13 | liling
# Processing Record 49 of Set 13 | omsukchan
# Processing Record 50 of Set 13 | lang son
# Processing Record 1 of Set 14 | katangli
# Processing Record 2 of Set 14 | hualmay
# Processing Record 3 of Set 14 | ferme-neuve
# Processing Record 4 of Set 14 | bonfim
# Processing Record 5 of Set 14 | krasnoselkup
# Processing Record 6 of Set 14 | kerrville
# Processing Record 7 of Set 14 | banda aceh
# Processing Record 8 of Set 14 | zonguldak
# Processing Record 9 of Set 14 | narsimhapur
# Processing Record 10 of Set 14 | maniitsoq
# Processing Record 11 of Set 14 | maridi
# Processing Record 12 of Set 14 | beyneu
# Processing Record 13 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 14 | san juan
# Processing Record 15 of Set 14 | mandan
# Processing Record 16 of Set 14 | quatre cocos
# Processing Record 17 of Set 14 | kahului
# Processing Record 18 of Set 14 | yuksekova
# Processing Record 19 of Set 14 | emerald
# Processing Record 20 of Set 14 | yasnyy
# Processing Record 21 of Set 14 | bereda
# Processing Record 22 of Set 14 | san jose
# Processing Record 23 of Set 14 | malangwa
# Processing Record 24 of Set 14 | pontes e lacerda
# Processing Record 25 of Set 14 | lagunillas
# Processing Record 26 of Set 14 | la crosse
# Processing Record 27 of Set 14 | isiro
# Processing Record 28 of Set 14 | teguise
# Processing Record 29 of Set 14 | iranshahr
# Processing Record 30 of Set 14 | ketchikan
# Processing Record 31 of Set 14 | caucasia
# Processing Record 32 of Set 14 | hamada
# Processing Record 33 of Set 14 | we
# City not found. Skipping...
# Processing Record 34 of Set 14 | mocuba
# Processing Record 35 of Set 14 | black diamond
# Processing Record 36 of Set 14 | bani
# Processing Record 37 of Set 14 | salta
# Processing Record 38 of Set 14 | miracema do tocantins
# Processing Record 39 of Set 14 | maseru
# Processing Record 40 of Set 14 | foso
# Processing Record 41 of Set 14 | bardiyah
# Processing Record 42 of Set 14 | sola
# Processing Record 43 of Set 14 | dunmore town
# Processing Record 44 of Set 14 | purpe
# Processing Record 45 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 14 | stephenville
# Processing Record 47 of Set 14 | brooks
# Processing Record 48 of Set 14 | yamada
# Processing Record 49 of Set 14 | tongren
# Processing Record 50 of Set 14 | roma
# Processing Record 1 of Set 15 | nouakchott
# Processing Record 2 of Set 15 | sur
# Processing Record 3 of Set 15 | durant
# Processing Record 4 of Set 15 | chara
# Processing Record 5 of Set 15 | belyy yar
# Processing Record 6 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 15 | nanchital
# Processing Record 8 of Set 15 | cayenne
# Processing Record 9 of Set 15 | chegdomyn
# Processing Record 10 of Set 15 | wewak
# Processing Record 11 of Set 15 | mogadishu
# Processing Record 12 of Set 15 | mabaruma
# Processing Record 13 of Set 15 | lazaro cardenas
# Processing Record 14 of Set 15 | beisfjord
# Processing Record 15 of Set 15 | shimoda
# Processing Record 16 of Set 15 | brae
# Processing Record 17 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 18 of Set 15 | beinamar
# Processing Record 19 of Set 15 | naron
# Processing Record 20 of Set 15 | minab
# Processing Record 21 of Set 15 | sao raimundo das mangabeiras
# Processing Record 22 of Set 15 | nishihara
# Processing Record 23 of Set 15 | asilah
# Processing Record 24 of Set 15 | san bartolome de tirajana
# Processing Record 25 of Set 15 | opuwo
# Processing Record 26 of Set 15 | kiunga
# Processing Record 27 of Set 15 | ahuimanu
# Processing Record 28 of Set 15 | puerto colombia
# Processing Record 29 of Set 15 | harindanga
# Processing Record 30 of Set 15 | antibes
# Processing Record 31 of Set 15 | camopi
# Processing Record 32 of Set 15 | matagami
# Processing Record 33 of Set 15 | oloron-sainte-marie
# Processing Record 34 of Set 15 | trinidad
# Processing Record 35 of Set 15 | gubkinskiy
# Processing Record 36 of Set 15 | cockburn town
# Processing Record 37 of Set 15 | abu samrah
# Processing Record 38 of Set 15 | sept-iles
# Processing Record 39 of Set 15 | aksaray
# Processing Record 40 of Set 15 | harper
# Processing Record 41 of Set 15 | filimonovo
# Processing Record 42 of Set 15 | isla aguada
# Processing Record 43 of Set 15 | akdepe
# Processing Record 44 of Set 15 | newport
# Processing Record 45 of Set 15 | los llanos de aridane
# Processing Record 46 of Set 15 | broken hill
# Processing Record 47 of Set 15 | solingen
# Processing Record 48 of Set 15 | borda da mata
# Processing Record 49 of Set 15 | amot
# Processing Record 50 of Set 15 | acapulco
# Processing Record 1 of Set 16 | gouyave
# Processing Record 2 of Set 16 | teshie
# Processing Record 3 of Set 16 | rebrikha
# Processing Record 4 of Set 16 | kropotkin
# Processing Record 5 of Set 16 | naze
# Processing Record 6 of Set 16 | udachnyy
# Processing Record 7 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 16 | mandurah
# Processing Record 9 of Set 16 | ust-kuyga
# Processing Record 10 of Set 16 | manta
# Processing Record 11 of Set 16 | oil city
# Processing Record 12 of Set 16 | panshi
# Processing Record 13 of Set 16 | manado
# Processing Record 14 of Set 16 | sorland
# Processing Record 15 of Set 16 | panguna
# Processing Record 16 of Set 16 | chickasha
# Processing Record 17 of Set 16 | tutzing
# Processing Record 18 of Set 16 | shahrud
# Processing Record 19 of Set 16 | pasighat
# Processing Record 20 of Set 16 | perigueux
# Processing Record 21 of Set 16 | rio tuba
# Processing Record 22 of Set 16 | sidhpura
# Processing Record 23 of Set 16 | srednekolymsk
# Processing Record 24 of Set 16 | cabrobo
# Processing Record 25 of Set 16 | half moon bay
# Processing Record 26 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 16 | longyearbyen
# Processing Record 28 of Set 16 | el astillero
# Processing Record 29 of Set 16 | riorges
# Processing Record 30 of Set 16 | hirado
# Processing Record 31 of Set 16 | monte alegre
# Processing Record 32 of Set 16 | itaituba
# Processing Record 33 of Set 16 | tateyama
# Processing Record 34 of Set 16 | puerto varas
# Processing Record 35 of Set 16 | zhuanghe
# Processing Record 36 of Set 16 | sheltozero
# Processing Record 37 of Set 16 | aranda de duero
# Processing Record 38 of Set 16 | victor harbor
# Processing Record 39 of Set 16 | sovetskiy
# Processing Record 40 of Set 16 | yatou
# Processing Record 41 of Set 16 | nome
# Processing Record 42 of Set 16 | davila
# Processing Record 43 of Set 16 | dzaoudzi
# Processing Record 44 of Set 16 | ganzhou
# Processing Record 45 of Set 16 | baishishan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Flin Flon  54.7682 -101.8650     17.44        27           0
# 1            Mataura -46.1927  168.8643     59.49        90         100
# 2              Kapaa  22.0752 -159.3190     79.48        60           0
# 3  Nizhniy Tsasuchey  50.5167  115.1333     11.07        68          99
# 4              Tiksi  71.6872  128.8694    -16.01        99         100
#
#    Wind Speed Country Current Description
# 0        8.05      CA           clear sky
# 1        2.17      NZ     overcast clouds
# 2        3.44      US           clear sky
# 3       23.94      RU     overcast clouds
# 4        2.44      RU     overcast clouds

# %%
# new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Flin Flon      CA  54.7682 -101.8650     17.44        27
# 1            Mataura      NZ -46.1927  168.8643     59.49        90
# 2              Kapaa      US  22.0752 -159.3190     79.48        60
# 3  Nizhniy Tsasuchey      RU  50.5167  115.1333     11.07        68
# 4              Tiksi      RU  71.6872  128.8694    -16.01        99
#
#    Cloudiness  Wind Speed Current Description
# 0           0        8.05           clear sky
# 1         100        2.17     overcast clouds
# 2           0        3.44           clear sky
# 3          99       23.94     overcast clouds
# 4         100        2.44     overcast clouds

# %%
# Export Dataframe into CSV file
city_data_df.to_csv("WeatherPy_Database.csv", header=True)
